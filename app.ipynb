# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (1.55.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (7.0.5)
# Requirement already satisfied: click<9,>=7.0 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (3.1.46)
# Requirement already satisfied: numpy<3,>=1.23 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (2.4.3)
# Requirement already satisfied: packaging>=20 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (26.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (12.1.1)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: protobuf<7,>=3.20 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (6.33.5)
# Requirement already satisfied: pyarrow>=7.0 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (23.0.1)
# Requirement already satisfied: requests<3,>=2.27 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (6.5.5)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=1.27.1 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.18.0)
# Requirement already satisfied: colorama in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3,>=2.27->streamlit) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3,>=2.27->streamlit) (2026.2.25)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in C:\Users\MADHUSUDAN MISHRA\AppData\Local\Programs\Python\Python311\Lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)

# %%
import streamlit as st
import numpy as np
import pickle

# 🎯 Load model, scaler, and features
model = pickle.load(open("model.pkl", "rb"))
scaler = pickle.load(open("scaler.pkl", "rb"))
features_list = pickle.load(open("features.pkl", "rb"))

# 🧠 Title
st.title("🧠 Mental Health Risk Prediction 💡")
st.write("Fill the details to predict if treatment is needed")

# 📋 Inputs
gender = st.selectbox("Gender", ["Male", "Female"])
occupation = st.selectbox("Occupation", ["Student", "Working Professional", "Self-employed", "Unemployed"])
self_employed = st.selectbox("Self Employed", ["Yes", "No"])
family_history = st.selectbox("Family History", ["Yes", "No"])
days_indoors = st.selectbox("Days Indoors", ["1-14", "15-30", "More than 30"])
growing_stress = st.selectbox("Growing Stress", ["Yes", "No"])
changes_habits = st.selectbox("Changes in Habits", ["Yes", "No"])
mental_history = st.selectbox("Mental Health History", ["Yes", "No"])
mood_swings = st.selectbox("Mood Swings", ["Yes", "No"])
coping_struggles = st.selectbox("Coping Struggles", ["Yes", "No"])
work_interest = st.selectbox("Work Interest", ["Low", "Medium", "High"])
social_weakness = st.selectbox("Social Weakness", ["Yes", "No"])
interview = st.selectbox("Mental Health Interview", ["Yes", "No"])
care_options = st.selectbox("Care Options", ["Yes", "No"])

# 🔄 Encoding
gender = 1 if gender == "Male" else 0
self_employed = 1 if self_employed == "Yes" else 0
family_history = 1 if family_history == "Yes" else 0
growing_stress = 1 if growing_stress == "Yes" else 0
changes_habits = 1 if changes_habits == "Yes" else 0
mental_history = 1 if mental_history == "Yes" else 0
mood_swings = 1 if mood_swings == "Yes" else 0
coping_struggles = 1 if coping_struggles == "Yes" else 0
social_weakness = 1 if social_weakness == "Yes" else 0
interview = 1 if interview == "Yes" else 0
care_options = 1 if care_options == "Yes" else 0

occupation_map = {"Student": 0, "Working Professional": 1, "Self-employed": 2, "Unemployed": 3}
days_map = {"1-14": 0, "15-30": 1, "More than 30": 2}
work_map = {"Low": 0, "Medium": 1, "High": 2}

occupation = occupation_map[occupation]
days_indoors = days_map[days_indoors]
work_interest = work_map[work_interest]

# 🔍 Prediction
if st.button("Predict"):
    input_data = np.array([[
        gender,
        occupation,
        self_employed,
        family_history,
        days_indoors,
        growing_stress,
        changes_habits,
        mental_history,
        mood_swings,
        coping_struggles,
        work_interest,
        social_weakness,
        interview,
        care_options
    ]])

    scaled_input = scaler.transform(input_data)
    prediction = model.predict(scaled_input)   # multi-class probabilities

    # ✅ Pick class with highest probability
    pred_class = int(np.argmax(prediction[0]))

    # ✅ Map class to result
    if pred_class == 0:
        result = "No Treatment Needed"
    elif pred_class == 1:
        result = "Needs Treatment"
    else:
        result = "Further Evaluation Recommended"

    confidence = round(np.max(prediction[0]) * 100, 2)

    # 🎨 Confidence-based colors
    if confidence > 70:
        st.success(f"🩺 Prediction: {result} (Confidence: {confidence}%)")
    elif confidence > 40:
        st.warning(f"🩺 Prediction: {result} (Confidence: {confidence}%)")
    else:
        st.error(f"🩺 Prediction: {result} (Confidence: {confidence}%)")
# Out:
# 2026-03-21 21:31:05.656 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.659 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.661 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.661 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.663 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.666 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.667 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.668 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.669 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.670 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.672 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.673 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.675 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.676 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.678 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.680 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.681 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.681 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.683 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.684 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.685 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.687 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.689 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.690 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.691 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.694 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.695 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.696 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.697 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.698 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.699 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.700 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.701 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.702 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.703 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.704 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.706 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.707 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.708 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.709 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.709 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.712 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.713 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.715 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.716 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.717 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.718 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.719 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.720 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.720 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.724 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.724 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.725 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.726 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.726 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.728 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.729 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.730 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.731 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.731 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.734 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.735 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.736 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.739 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.740 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.741 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.741 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.743 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.744 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.744 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.745 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.746 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.747 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.748 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.749 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.750 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.751 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.752 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.754 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.757 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.758 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.758 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.759 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.761 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.761 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.762 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.765 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.765 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.766 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.768 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.769 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.770 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.772 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.774 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.775 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.776 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.777 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.778 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.778 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.779 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.781 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.783 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.783 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.784 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.785 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-21 21:31:05.786 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\MADHUSUDAN MISHRA\Mental_Health_Project
